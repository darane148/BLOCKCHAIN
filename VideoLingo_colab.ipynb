# %% [markdown]
# <a href="https://colab.research.google.com/github/darane148/BLOCKCHAIN/blob/main/VideoLingo_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to VideoLingo! 🎉🚀
# #### This colab file allows you to quickly experience the full functionality in just 5 minutes! ⏱️✨ Before you begin, you may need to prepare some keys. 🔑🗝️ Please read https://videolingo.io/docs/start to get ready. 📚👍
# #### *Please use a T4 GPU to execute this colab for optimal performance.

# %% [markdown]
# ## 1. Clone VideoLingo repo 📥

# %%
# !git clone https://github.com/Huanshere/VideoLingo.git
# %cd VideoLingo
# Out:
# Cloning into 'VideoLingo'...
# remote: Enumerating objects: 5820, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 5820 (delta 7), reused 1 (delta 1), pack-reused 5791 (from 2)
# Receiving objects: 100% (5820/5820), 15.51 MiB | 31.38 MiB/s, done.
# Resolving deltas: 100% (3727/3727), done.
# /content/VideoLingo

# %% [markdown]
# ## 2. Installation 🚀
# this takes around 4 mins

# %%
# !python install.py
# Out:
# /content/VideoLingo/install.py:8: SyntaxWarning: invalid escape sequence '\ '
#   \ \   / (_) __| | ___  ___ | |   (_)_ __   __ _  ___
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (13.9.4)
# Collecting ruamel.yaml
#   Downloading ruamel_yaml-0.19.1-py3-none-any.whl.metadata (16 kB)
# Collecting InquirerPy
#   Downloading InquirerPy-0.3.4-py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2026.4.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich) (2.20.0)
# Collecting pfzy<0.4.0,>=0.3.1 (from InquirerPy)
#   Downloading pfzy-0.3.4-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from InquirerPy) (3.0.52)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich) (0.1.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit<4.0.0,>=3.0.1->InquirerPy) (0.6.0)
# Downloading ruamel_yaml-0.19.1-py3-none-any.whl (118 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.1/118.1 kB 5.8 MB/s eta 0:00:00
# Downloading InquirerPy-0.3.4-py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.7/67.7 kB 7.2 MB/s eta 0:00:00
# Downloading pfzy-0.3.4-py3-none-any.whl (8.5 kB)
# Installing collected packages: ruamel.yaml, pfzy, InquirerPy
# Successfully installed InquirerPy-0.3.4 pfzy-0.3.4 ruamel.yaml-0.19.1
# ╔══════════════════════════ 🌏 ═══════════════════════════╗
# ║                                                         ║
# ║ __     ___     _            _     _                     ║
# ║ \ \   / (_) __| | ___  ___ | |   (_)_ __   __ _  ___    ║
# ║  \ \ / /| |/ _` |/ _ \/ _ \| |   | | '_ \ / _` |/ _ \   ║
# ║   \ V / | | (_| |  __/ (_) | |___| | | | | (_| | (_) |  ║
# ║    \_/  |_|\__,_|\___|\___/|_____|_|_| |_|\__, |\___/   ║
# ║                                           |___/         ║
# ║                                                         ║
# ╚═════════════════════════════════════════════════════════╝
# e
# ctionner la langue / Выберите язык:
#   🇬🇧 English
# ❯ 🇨🇳 简体中文
#   🇭🇰 繁体中文
#   🇯🇵 日本語
#   🇪🇸 Español
#   🇷🇺 Русский
#   🇫🇷 FrançaisWARNING: your terminal doesn't support cursor position requests (CPR).
# e
# ctionner la langue / Выберите язык:
#   🇬🇧 English
# ❯ 🇨🇳 简体中文
#   🇭🇰 繁体中文
#   🇯🇵 日本語
#   🇪🇸 Español
#   🇷🇺 Русский
#   🇫🇷 Français

# %% [markdown]
# ## 3. Register and Obtain Ngrok Token 🔑
#
# 1. Visit the [Ngrok official website](https://ngrok.com/) and register for an account.
# 2. After logging in, find the "Your Authtoken" section on the dashboard page, or directly visit [Ngrok Token](https://dashboard.ngrok.com/get-started/your-authtoken).
# 3. Copy your Ngrok Authtoken.
#
# After completing these steps, please fill in your ngrok token in the next section of code and proceed.
#
# ---
#
# ## 3. 注册并获取 Ngrok 令牌 🔑
#
# 1. 访问 [Ngrok 官方网站](https://ngrok.com/) 并注册账户。
# 2. 登录后，在仪表板页面找到"Your Authtoken"部分，或直接访问 [Ngrok 令牌](https://dashboard.ngrok.com/get-started/your-authtoken)。
# 3. 复制您的 Ngrok Authtoken。
#
# 完成这些步骤后，请在下一节代码中填入您的 ngrok 令牌并继续。

# %%
# !pip install pyngrok
from pyngrok import ngrok

#! SET Ngrok Authtoken Here
ngrok.set_auth_token("YOUR_TOKEN_HERE")
# Out:
# Requirement already satisfied: pyngrok in /usr/local/lib/python3.10/dist-packages (7.2.0)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.10/dist-packages (from pyngrok) (6.0.2)

# %% [markdown]
# ## 🎈 4. Streamlit GO !!!
# Click the NgrokChannel URL to start your VideoLingo Journey.
#
# > tips: You can set your Language down the sidebar on the left.

# %%
import subprocess
import threading
import sys
from pyngrok import ngrok
from rich import print as rprint
from rich.panel import Panel

def print_output(process):
    for line in iter(process.stdout.readline, ''):
        sys.stdout.write(line)
    for line in iter(process.stderr.readline, ''):
        sys.stderr.write(line)

# Start Streamlit
streamlit_process = subprocess.Popen(
    ["streamlit", "run", "st.py"],
    stdout=subprocess.PIPE,
    stderr=subprocess.PIPE,
    universal_newlines=True,
    bufsize=1
)

# Create and start the output printing thread
output_thread = threading.Thread(target=print_output, args=(streamlit_process,))
output_thread.start()

# Create a tunnel using ngrok
public_url = ngrok.connect(8501)
rprint(Panel(f"Streamlit is available at Ngrok ⬇️", expand=False))
print(f"Click 👉 {public_url}")

# Keep the program running
ngrok_process = ngrok.get_ngrok_process()
try:
    streamlit_process.wait()
except KeyboardInterrupt:
    print("Interrupted by user, shutting down...")
finally:
    ngrok.kill()
    streamlit_process.terminate()
    output_thread.join()
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
# ╭───────────────────────────────────╮
# │ Streamlit is available at Ngrok ⬇️ │
# ╰───────────────────────────────────╯
# Click 👉 NgrokTunnel: "https://0308-34-125-196-161.ngrok-free.app" -> "http://localhost:8501"
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.125.196.161:8501
#
#   Stopping...
# Interrupted by user, shutting down...
